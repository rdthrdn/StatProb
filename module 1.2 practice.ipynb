# %% [markdown]
# # Module 1.2. Measures of Variability
# SOAL 1 : Dalam suatu liga sepak bola, dipilih secara acak 10 pemain dari klub yang berbeda dan diketahui jumlah gol yang mereka raih dalam musim ini adalah: 19, 10, 10, 12, 13, 15, 14, 13, 9, 17. Lakukan analisis terhadap sebaran data dari dataset yang diberikan. Manakah ukuran sebaran yang paling mampu menggambarkan sebaran data dengan baik?

# %%
# Membuat list dari jumlah gol yang diraih oleh 10 pemain
gol = [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]

# Menghitung ukuran sebaran data, yaitu rentang, kuartil, simpangan kuartil, dan simpangan baku
import statistics
rentang = max(gol) - min(gol)
kuartil1 = statistics.quantiles(gol, n=4)[0]
kuartil2 = statistics.quantiles(gol, n=4)[1]
kuartil3 = statistics.quantiles(gol, n=4)[2]
simpangan_kuartil = kuartil3 - kuartil1
simpangan_baku = statistics.stdev(gol)

# Mencetak hasil perhitungan
print("Rentang jumlah gol adalah", rentang)
print("Kuartil 1 jumlah gol adalah", kuartil1)
print("Kuartil 2 jumlah gol adalah", kuartil2)
print("Kuartil 3 jumlah gol adalah", kuartil3)
print("Simpangan kuartil jumlah gol adalah", simpangan_kuartil)
print("Simpangan baku jumlah gol adalah", simpangan_baku)

# Menggambar boxplot dari list
import matplotlib.pyplot as plt
plt.boxplot(gol)
plt.xlabel("Jumlah gol")
plt.title("Boxplot jumlah gol yang diraih oleh 10 pemain")
plt.show()
# Out:
# Rentang jumlah gol adalah 10
# Kuartil 1 jumlah gol adalah 10.0
# Kuartil 2 jumlah gol adalah 13.0
# Kuartil 3 jumlah gol adalah 15.5
# Simpangan kuartil jumlah gol adalah 5.5
# Simpangan baku jumlah gol adalah 3.190262963734773

# %% [markdown]
# SOAL 2 : Berikut adalah nilai UAS pada mata pelajaran matematika di kelas A: 95, 35, 50, 65, 70, 85, 25, 100, 80, 90, 45, 40, 35, 20, 75, 50, 40, 60, 80, 75. Menggunakan Mean, Median, dan Modus, coba gambarkan pusat distribusi data berikut. Manakah yang paling bagus?

# %%
# Membuat list dari tinggi pemain dalam tim olahraga
tinggi = [180, 185, 175, 190, 170, 195, 165]

# Menggambar histogram dari list
import matplotlib.pyplot as plt
plt.hist(tinggi, bins=6)
plt.xlabel("Tinggi (cm)")
plt.ylabel("Frekuensi")
plt.title("Histogram tinggi pemain dalam tim olahraga")
plt.show()
